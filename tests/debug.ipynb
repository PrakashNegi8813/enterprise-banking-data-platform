# %%
# %sql
SELECT *
FROM consumerbank.metadata.ingestion_config
ORDER BY dataset_name, layer_order;

# %%
display(dbutils.fs.ls(
    "abfss://landing@stconsumerbankdev001.dfs.core.windows.net/branch"
))

# %%
df = spark.read.parquet(
    "abfss://landing@stconsumerbankdev001.dfs.core.windows.net/branch/branch_master.parquet"
)

display(df)

print(df.count())

# %%
from framework.orchestrator import run_pipeline

run_pipeline(
    spark=spark,
    dataset="branch"
)

# %%
# %sql
SELECT
    dataset_name,
    layer,
    source_container,
    source_path,
    source_file,
    file_format,
    source_type
FROM consumerbank.metadata.ingestion_config
WHERE dataset_name = 'branch'
  AND layer = 'BRONZE';

# %%
# %sql
UPDATE consumerbank.metadata.ingestion_config
SET source_file = 'branch_master.parquet'
WHERE dataset_name = 'branch'
  AND layer = 'BRONZE';

# %%
# %sql
SELECT source_path, source_file
FROM consumerbank.metadata.ingestion_config
WHERE dataset_name='branch'
AND layer='BRONZE';

# %%
# %sql
UPDATE consumerbank.metadata.ingestion_config
SET source_file = 'product_master.parquet'
WHERE dataset_name = 'product'
  AND layer = 'BRONZE';

# %%
from framework.orchestrator import run_pipeline

run_pipeline(
    spark=spark,
    dataset="branch"
)

# %%
# %sql
SELECT COUNT(*) FROM consumerbank.bronze.branch_master;

SELECT COUNT(*) FROM consumerbank.bronze.product_master;

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
SHOW SCHEMAS IN consumerbank;

# %%
# %sql
SHOW TABLES IN consumerbank.bronze;

# %%
# %sql
SELECT target_catalog, target_schema, target_table
FROM consumerbank.metadata.ingestion_config
WHERE dataset_name='branch'
AND layer='BRONZE';

# %%
# %sql
SELECT COUNT(*) FROM consumerbank.bronze.branch;

SELECT COUNT(*) FROM consumerbank.silver.branch;

SELECT COUNT(*) FROM consumerbank.gold.branch;

SELECT * FROM consumerbank.gold.branch LIMIT 10;

# %%
# %sql
-- Audit logs
SELECT *
FROM consumerbank.metadata.pipeline_audit
ORDER BY end_time DESC;

# %%
# %sql
-- Watermark table
SELECT *
FROM consumerbank.metadata.watermark;

# %%
from framework.orchestrator import run_pipeline

run_pipeline(
    spark=spark,
    dataset="product"
)

# %%
# %sql
SHOW TABLES IN consumerbank.metadata;

# %%
# %sql
SELECT MAX(last_updated_date)
FROM consumerbank.gold.branch;

# %%
# %sql
SELECT dataset_name, layer, watermark_column
FROM consumerbank.metadata.ingestion_config;

# %%
from framework.orchestrator import run_pipeline

run_pipeline(
    spark=spark,
    dataset="product"
)

# %%
# %sql
SELECT COUNT(*) FROM consumerbank.bronze.product;
SELECT COUNT(*) FROM consumerbank.silver.product;
SELECT COUNT(*) FROM consumerbank.gold.product;

# %%
# %sql
SELECT *
FROM consumerbank.metadata.pipeline_audit
ORDER BY end_time DESC;

# %%
run_pipeline(spark, "branch")

# %%
# %sql
DESCRIBE consumerbank.bronze.branch;

# %%
# %sql
SELECT Branch_ID, Branch_Name, Last_Updated_TS
FROM consumerbank.silver.branch;

# %%
# %sql
UPDATE consumerbank.bronze.branch
SET
    Branch_Name = 'LKO Branch',
    Last_Updated_TS = current_timestamp()
WHERE Branch_ID = 'BR1018';

# %%
# %sql
SELECT Branch_ID, Branch_Name, Last_Updated_TS
FROM consumerbank.bronze.branch;

# %%
# %sql
SELECT Branch_ID, Branch_Name, Last_Updated_TS
FROM consumerbank.bronze.branch
WHERE Branch_ID = 'BR1018';

# %%
from framework.orchestrator import run_pipeline

run_pipeline(
    spark=spark,
    dataset="branch"
)

# %%
# %sql
SELECT
    Branch_ID,
    Branch_Name,
    Last_Updated_TS
FROM consumerbank.silver.branch
WHERE Branch_ID='BR1018';

# %%
# %sql
SELECT Branch_ID, Branch_Name
FROM consumerbank.bronze.branch
LIMIT 10;

# %%
# %sql
SELECT Branch_ID, Branch_Name
FROM consumerbank.bronze.branch
WHERE Branch_ID = 'BR1018';

# %%
# %sql
SELECT *
FROM consumerbank.bronze.branch
WHERE Branch_ID = 'BR1018';

# %%
# %sql
UPDATE consumerbank.bronze.branch
SET
    Branch_Name = 'LKO Branch',
    Last_Updated_TS = current_timestamp()
WHERE Branch_ID = 'BR1018';

# %%
# %sql
SELECT Branch_ID,
       Branch_Name,
       Last_Updated_TS
FROM consumerbank.bronze.branch
WHERE Branch_ID = 'BR1018';

# %%
from framework.orchestrator import run_pipeline

run_pipeline(
    spark=spark,
    dataset="branch"
)

# %%
# %sql
SELECT
    Branch_ID,
    Branch_Name,
    Last_Updated_TS
FROM consumerbank.bronze.branch
WHERE Branch_ID='BR1018';

# %%
# %sql
SELECT dataset_name,
       layer,
       load_type
FROM consumerbank.metadata.ingestion_config
WHERE dataset_name='branch';
